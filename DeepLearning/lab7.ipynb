# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clone()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext spacy
# !python -m spacy download en
# !python -m spacy download es
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"

# %% [markdown]
# #Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ##Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'
    
    # scores = QK^T/scale
    dk = query.size()[2] # getting dimesion of query
    scale = dk ** (1/2) # scale is sqrt of the dimension
    scores = torch.matmul(query, torch.transpose(key, 1, 2))/scale
    
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
        
    output = F.softmax(scores, dim=2)
    output = torch.matmul(output, value)
    
    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()

        self.h = h
        dim_attn_vect = 64

        # Make an attention head (linear layers for q, k, and v)
        self.w_q = nn.Linear(d_model, dim_attn_vect)
        self.w_k = nn.Linear(d_model, dim_attn_vect)
        self.w_v = nn.Linear(d_model, dim_attn_vect)

        # Create final linear layer to pass to next layer in encoder
        self.final_linear = nn.Linear(dim_attn_vect * h, d_model) 

        
        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.w_q_h = clones(self.w_q, h)
        self.w_k_h = clones(self.w_k, h)
        self.w_v_h = clones(self.w_v, h)

    def forward(self, query, key, value, mask):
        # For each attention head
            # Pass the query, key, value through their respective layers
            # Compute scaled dot-product attention on the output

        outputs = []
        for i in range(self.h):
          q = self.w_q_h[i](query)
          k = self.w_q_h[i](key)
          v = self.w_q_h[i](value)
          outputs.append(attention(q, k, v, mask))
        
        # concatenate h outputs (z)
        concatenated_head = torch.concat(outputs, 2)
        final_z = self.final_linear(concatenated_head)
        return final_z

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es')
spacy_en = spacy.load('en')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
spanish_text = open('./spanish','r')
english_text = open('./english', 'r')
english_lines = list(english_text)
spanish_lines = list(spanish_text)

fields = (["src", SRC], ["trg", TGT])
examples = [torchtext.legacy.data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = torchtext.legacy.data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ##Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train
# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	En la cubierta
# Translation:	In the Cover
# Target:		On the Cover
#
# Spanish:	Prepárense bien .
# Translation:	Prepare well .
# Target:		Prepare yourself well .
#
# Spanish:	Las prioridades en conflicto
# Translation:	The priorities in the problem in the public priorities
# Target:		<unk> Priorities
#
# Spanish:	El Salvador dijo :
# Translation:	The Savior said :
# Target:		The Savior said :
#
# Spanish:	Por Stephen W. Owen
# Translation:	By Stephen W. Owen
# Target:		By Stephen W. Owen
#
# Spanish:	3 Nefi 27:19 .
# Translation:	3 Nephi 10:21 .
# Target:		3 Nephi 27:19 .
#
# Spanish:	mi deleite son ,
# Translation:	I heard my plea are ,
# Target:		Hath it not been my one delight ,
#
# Spanish:	La paz en el hogar
# Translation:	Peace
# Target:		For Peace at Home
#
# Spanish:	Las <unk> de la Resurrección
# Translation:	The Resurrection of the Resurrection
# Target:		The <unk> of the Resurrection
#
# Spanish:	Véase 1 Juan 1:9 .
# Translation:	See John 1:9 .
# Target:		See 1 John 1:9 .
#
# Spanish:	Doctrina y Convenios 109:44 .
# Translation:	Doctrine and Covenants 38:30 .
# Target:		Doctrine and Covenants 109:44 .
#
# Spanish:	Dios aún los llama .
# Translation:	God still is still called .
# Target:		God still calls to you .
#
# Spanish:	Sesión del sábado por la mañana
# Translation:	Saturday Morning Session
# Target:		Saturday Morning Session
#
# Spanish:	Por el élder Dallin H. Oaks
# Translation:	By Elder Dallin H. Oaks
# Target:		By Elder Dallin H. Oaks
#
# Spanish:	Por el élder Quentin L. Cook
# Translation:	By Elder Quentin L. Cook
# Target:		By Elder Quentin L. Cook
#
# Spanish:	Véase Doctrina y Convenios 128:20 .
# Translation:	See Doctrine and Covenants 38:30 .
# Target:		See Doctrine and Covenants 128:20 .
#
# Spanish:	Llamó a los Doce Apóstoles .
# Translation:	He will take the Twelve Apostles .
# Target:		He called the Twelve Apostles .
#
# Spanish:	Véase Doctrina y Convenios 45:26 .
# Translation:	See Doctrine and Covenants 45:26 .
# Target:		See Doctrine and Covenants 45:26 .
#
# Spanish:	Por eso se los necesita .
# Translation:	By this is that the needs .
# Target:		This is why you are needed .
#
# Spanish:	cuando tentaciones <unk> con furor ,
# Translation:	When temptations , with temptations ,
# Target:		When you are discouraged , thinking all is lost ,
#
# Spanish:	El crecimiento de la Iglesia en África
# Translation:	The growth of the Church in Africa in Africa
# Target:		Church <unk> in Africa
#
# Spanish:	Los dos tienen una necesidad específica .
# Translation:	The two need a need a need to the need to the need to the need to the need to us .
# Target:		Each has a specific need .
#
# Spanish:	La maravilla y el privilegio del sacerdocio
# Translation:	The fact and privilege of the priesthood of the priesthood of the privilege of the privilege of the priesthood of the priesthood and the priesthood of the priesthood of the priesthood of the priesthood .
# Target:		The Wonder and Privilege of the Priesthood
#
# Spanish:	mi gozo es , y canción ,
# Translation:	My joy is my promise , and song ,
# Target:		He is my joy and my song .
#
# Spanish:	Existen diferentes relatos sobre Florence Chadwick .
# Translation:	There are different about these stories .
# Target:		Additional <unk> accounts about Florence Chadwick exist .
#
# Spanish:	y siempre guardarlo con grande amor .
# Translation:	And always , never with great love .
# Target:		I ’ll never , no never , no never forsake !
#
# Spanish:	La función de las hermanas en la Iglesia
# Translation:	The role of the sisters in the Church
# Target:		Role of Sisters in the Church
#
# Spanish:	¿ Qué podía hacer yo sino aceptar ?
# Translation:	What could do ?
# Target:		What could I do but accept ?
#
# Spanish:	Sí , ¡ podemos ganar y ganaremos !
# Translation:	Yes , we can keep it !
# Target:		Yes , We Can and Will Win !
#
# Spanish:	Estoy agradecido por mis muchas bendiciones ” .
# Translation:	I am grateful for many blessings . ”
# Target:		I am grateful for my many blessings . ”
#
# Spanish:	Él Espíritu hablará paz a su alma ;
# Translation:	He will speak peace to your soul .
# Target:		The Spirit will speak peace to your soul .
#
# Spanish:	Lo mismo sucedió con los cuatro hermanos .
# Translation:	It happened with four brethren .
# Target:		And so it was with all four of the brethren .
#
# Spanish:	Mis preguntas me llevaron a una fe mayor .
# Translation:	My questions were a great faith .
# Target:		My questions led to increased faith .
#
# Spanish:	Sus pensamientos son más elevados que nuestros pensamientos .
# Translation:	His thoughts are more than our thoughts .
# Target:		His thoughts are higher than our thoughts .
#
# Spanish:	Así lo hicieron , y salvaron su matrimonio .
# Translation:	So he did , and his marriage .
# Target:		They did so and their marriage was saved .
#
# Spanish:	El Espíritu Santo es esencial para la Restauración .
# Translation:	The Holy Ghost is essential to the Restoration .
# Target:		The Holy Ghost is central to the Restoration .
#
# Spanish:	Son pocos , pero su espíritu es grande .
# Translation:	They are few , but your spirit .
# Target:		They are few in number but large in spirit .
#
# Spanish:	<unk> se puede traducir como " girar " .
# Translation:	Let us were " as a physician . "
# Target:		<unk> can be translated as " to turn . "
#
# Spanish:	Recibí una de esas bendiciones hace unos días .
# Translation:	I received a blessings of these days .
# Target:		I received one of those blessings just a few weeks ago .
#
# Spanish:	“ Te amo y no quiero lastimarte ” .
# Translation:	“ I love and feel and never . ”
# Target:		“ I love you , and I do n’t want to hurt you . ”
#
# Spanish:	¿ El apretón de manos de un amigo cercano ?
# Translation:	Do you go from a friend ?
# Target:		The <unk> of a close friend ?
#
# Spanish:	Jesucristo , haciendo uso de Su albedrío , dijo :
# Translation:	Jesus Christ , His use of His agency , said :
# Target:		Jesus Christ , using His agency , said :
#
# Spanish:	La fe no es una casualidad , sino una elección
# Translation:	Faith is not a choice , but a choice choice choice choice choice choice choice choice .
# Target:		Faith Is Not by <unk> , but by Choice
#
# Spanish:	Véanse 2 Nefi 9:8–9 ; Doctrina y Convenios 93:34 .
# Translation:	See 2 Nephi 27:14–15 ; Doctrine and Covenants 115:5 .
# Target:		See 2 Nephi 9:8–9 ; Doctrine and Covenants 93:34 .
#
# Spanish:	Él respondió : " Yo soy tu marido " .
# Translation:	He replied , " I am thy husband . "
# Target:		He answered , " I am your husband . "
#
# Spanish:	<unk> las cosas de mamá para llevarlas a casa .
# Translation:	They Spoke to the mother of the house .
# Target:		We gathered up my mother ’s things to take home .
#
# Spanish:	Al sabio consejo del presidente Monson agrego mi testimonio .
# Translation:	As wise counsel of President Monson , I add my testimony .
# Target:		To President Monson ’s wise counsel , I add my witness .
#
# Spanish:	Sabía que me esperaba la batalla de mi vida .
# Translation:	I knew that the battle of the battle .
# Target:		I knew that I would be in for the fight of my life .
#
# Spanish:	Los que estén en contra , con la misma señal .
# Translation:	Those opposed , you , with the same sign .
# Target:		Those opposed , by the same sign .
#
# Spanish:	El presidente Monson pide más misioneros ; anuncia cinco nuevos templos
# Translation:	President Monson asks .
# Target:		President Monson Calls for Missionaries , Announces Five New Temples
#
# Spanish:	Otros decidieron unirse a quienes se burlaban en el edificio .
# Translation:	Other kinds of those who are in the building .
# Target:		Others decided to join the mockers in the building .
#
# Spanish:	Los lamanitas comenzaron la guerra contra el pueblo de Limhi .
# Translation:	The Lamanites began the war against war .
# Target:		The Lamanites had waged war against the people of Limhi .
#
# Spanish:	Cenicienta tiene que soportar a sus malvadas <unk> y <unk> .
# Translation:	They has come to endure their hands and their heads .
# Target:		Cinderella has to endure her wicked <unk> and evil <unk> .
#
# Spanish:	No fue fácil , y tuvo que superar muchos obstáculos .
# Translation:	It was n’t easy , and many things .
# Target:		It was not easy and he had many obstacles to overcome .
#
# Spanish:	Quizá haya mandamientos que escojamos no cumplir por un tiempo .
# Translation:	Perhaps it has never forgotten a time to make a time .
# Target:		There may be commandments that we choose for a time to ignore .
#
# Spanish:	Testifico que Jesucristo es el Hijo viviente del Dios viviente .
# Translation:	I testify that Jesus Christ is the living God .
# Target:		I testify that Jesus Christ is the living Son of the living God .
#
# Spanish:	Entonces les dijo : Sacad ahora y <unk> al <unk> .
# Translation:	Then he said , and then put on the roof .
# Target:		And he saith unto them , Draw out now , and bear unto the governor of the feast .
#
# Spanish:	Véase La enseñanza : El llamamiento más importante , pág. 66 .
# Translation:	See Teaching , the most important calling .
# Target:		See Teaching , No Greater Call , <unk> .
#
# Spanish:	Nuestro Salvador fue “ despreciado y rechazado de los hombres ” .
# Translation:	Our Savior was “ the people of the men . ”
# Target:		Our Savior was “ despised and rejected of men . ”
#
# Spanish:	Véase Introducción del Libro de Mormón ; Doctrina y Convenios <unk> .
# Translation:	See Merriam - day of Mormon ; Doctrine and Covenants 84:20 .
# Target:		See Book of Mormon introduction ; Doctrine and Covenants <unk> .
#
# Spanish:	Véase “ <unk> and <unk> Stories about Children , ” <unk> .
# Translation:	See “ Hold on the Children and Responsibilities of the Journey . ”
# Target:		See “ <unk> and <unk> Stories about Children , ” <unk> .
#
# Spanish:	Caminaba lentamente , como si se acercara a un gran peligro ,
# Translation:	I would be as though a great thing , a great - resistant to be a great - term , if it .
# Target:		He walked slowly as if he were going into great danger .
#
# Spanish:	El momento de estudiar , gota a gota , es ahora .
# Translation:	The moment of study , even even is now .
# Target:		The time is now to pursue your education — drop by drop .
#
# Spanish:	De nuestras fuentes de vida emanarán nuestros hijos , nuestra familia .
# Translation:	In our lives of our lives , our families , our family .
# Target:		From our fountains of life will spring our children , our family .
#
# Spanish:	<unk> su corazón en oración y los cielos les fueron abiertos .
# Translation:	They wept with prayer and the heaven .
# Target:		They poured out their hearts , and the heavens were opened to them .
#
# Spanish:	“ ¿ Cómo es que no guardáis los mandamientos del Señor ?
# Translation:	“ How is not the commandments of the commandments of the Lord ?
# Target:		“ How is it that ye do not keep the commandments of the Lord ?
#
# Spanish:	Guía para la familia , folleto , 2001 , pág. 12 .
# Translation:	( page page for the Strength , 12 , 12 .
# Target:		Our Family : A Practical Guide for Building a Gospel - Centered Home ( pamphlet , 1980 ) , 6 .
#
# Spanish:	No pueden esperar a que venga por sí mismo a la Iglesia .
# Translation:	We can not wait to be for the Church .
# Target:		They had to go to his home and visit him .
#
# Spanish:	Él es Aquél que fue asesinado y Aquél que vive de nuevo .
# Translation:	He is that he was baptized and who lives .
# Target:		He is He who was slain and He who liveth again .
#
# Spanish:	Nuestra conducta y opciones diarias deben estar en armonía con nuestras metas .
# Translation:	Our conduct and decisions are in harmony with our own goals .
# Target:		Our daily conduct and choices should be consistent with our goals .
#
# Spanish:	Véanse Mateo 16:25 ; 1 Nefi 2:20 ; Doctrina y Convenios 14:7 .
# Translation:	See Matthew 16:25 ; 1 Nephi 14:7 ; Doctrine and Covenants 14:7 .
# Target:		See Matthew 16:25 ; 1 Nephi 2:20 ; Doctrine and Covenants 14:7 .
#
# Spanish:	Un pequeño cuerpo comienza a formarse siguiendo un modelo de magnífica complejidad .
# Translation:	A small body begins with a pattern of a magnificent pattern of the weak .
# Target:		A tiny body begins to form after a pattern of magnificent complexity .
#
# Spanish:	Abarca 4 hectáreas , es decir , una <unk> de la ciudad .
# Translation:	It is true , it is a golden city of the city .
# Target:		It covers 10 <unk> ( 4 ha ) , or one city block .
#
# Spanish:	“ Y calzados los pies con la preparación del evangelio de paz ;
# Translation:	“ And the feet with the preparation of the gospel of the gospel .
# Target:		“ And your feet shod with the preparation of the gospel of peace ;
#
# Spanish:	Coro ( sin anuncio ) : " A quienes forjaron la nación "
# Translation:	Choir ( without announcement ) : " The mountains "
# Target:		Choir ( without announcement ) : " They , the Builders of the Nation "
#
# Spanish:	Testifico del poder de nuestros convenios y de las bendiciones del templo .
# Translation:	I testify of the power of the blessings of the temple .
# Target:		I testify of the power of our covenants and the blessings of the temple .
#
# Spanish:	Después , escucharemos al Obispo W. Christopher Waddell , del Obispado Presidente .
# Translation:	After we will hear the Presiding Bishopric , the Presiding Bishopric .
# Target:		After the singing , we will hear from Bishop W. Christopher Waddell of the Presiding Bishopric .
#
# Spanish:	Ese hombre era un ejemplo de lo que significa la disposición para cambiar .
# Translation:	This man was a example of what it means to change .
# Target:		This man exemplified a willingness to change .
#
# Spanish:	El obispo y su consejo de barrio analizan el progreso de cada investigador .
# Translation:	Bishop and his bishop and his ward .
# Target:		The bishop and his ward council discuss every progressing investigator .
#
# Spanish:	Y algunos se ven tentados por los apetitos sexuales prohibidos por nuestro Creador .
# Translation:	And some of the other efforts to the Creator .
# Target:		And some are tempted by sexual appetites forbidden by our Creator .
#
# Spanish:	“ La Familia : Una Proclamación para el Mundo ” , pág. 129 .
# Translation:	“ The Family : A Proclamation to the World , ” 129 .
# Target:		“ The Family : A Proclamation to the World , ” 129 .
#
# Spanish:	Me esforzaré para mantenerme digno de la bendición que significa nuestra unión eterna .
# Translation:	I will strive to be worthy to be worthy to our eternal blessing .
# Target:		I will strive to remain worthy of the blessing of our eternal union .
#
# Spanish:	Él es “ el camino , y la verdad y la vida ” .
# Translation:	He is “ the way , and the truth . ”
# Target:		He is “ the way , the truth , and the life . ”
#
# Spanish:	“ hágase tu voluntad , y sea tuya la gloria para siempre ” .
# Translation:	“ Thy will be thy will be done and the glory . ”
# Target:		“ Thy will be done , and the glory be thine forever . ”
#
# Spanish:	El Señor declaró : “ … yo puedo efectuar mi propia obra ” .
# Translation:	The Lord declared , “ I can do my own work . ”
# Target:		The Lord declared , “ I am able to do mine own work . ”
#
# Spanish:	Pero su matrimonio era mucho más que el profundo amor que se tenían .
# Translation:	But his marriage was much more love the love that love was very .
# Target:		But their marriage was more than just the deep love they had for each other .
#
# Spanish:	‘ Puedo prestar servicio con todo mi corazón , mente y fuerza ’ .
# Translation:	‘ I can serve with all my heart , and strength . ’
# Target:		“ ‘ I can serve with all of my heart , mind , and strength . ’
#
# Spanish:	El coro abrirá esta reunión cantando : " Mirad a Sion hermosa " .
# Translation:	The choir will open this meeting , " Let Zion . "
# Target:		The choir will open this meeting by singing : " Let Zion in Her Beauty Rise . "
#
# Spanish:	Dicho gozo llega como una paz en medio de la adversidad o del pesar .
# Translation:	The joy comes as a peace or peace in adversity .
# Target:		That joy comes as peace amidst hardship or heartache .
#
# Spanish:	El plan de redención de nuestro Padre Celestial es para ustedes y para mí .
# Translation:	The plan of redemption is our Heavenly Father is to me .
# Target:		Heavenly Father ’s plan of redemption is for you and me .
#
# Spanish:	La fe en Jesucristo brinda incluso más dones que la sanidad y la paz .
# Translation:	Faith in Jesus Christ provides more gifts and spiritual gifts .
# Target:		Faith in Jesus Christ brings even more gifts than healing and peace .
#
# Spanish:	Me acudieron a la mente y los labios las palabras de que ella viviría .
# Translation:	I wrote to mind and mind and the words of the words of her words .
# Target:		The words came to my mind and my lips that she would live .
#
# Spanish:	En más de una ocasión nos ha hecho <unk> ánimo y nos ha fortalecido .
# Translation:	In more than a time has done and destructive .
# Target:		And more than once He has made us cheerful as well as strong .
#
# Spanish:	Muchas de ellas expresan que su mayor deseo es estar unidas eternamente como familia .
# Translation:	Many of them are your greatest desire is true to be worthy .
# Target:		Many express that their greatest desire is to be united eternally as a family .
#
# Spanish:	Doctrina y Convenios 46:11–12 ; véanse también Moroni 10:8–17 ; Doctrina y Convenios 13–16 .
# Translation:	Doctrine and Covenants 8:2 ; see also Moroni 10:8–17 ; Doctrine and Covenants 38:30 .
# Target:		Doctrine and Covenants 46:11–12 ; see also Moroni 10:8–17 ; Doctrine and Covenants 13–16 .
#
# Spanish:	Las bendiciones que el Señor ha prometido a quienes <unk> al mundo son grandiosas .
# Translation:	The blessings that the Lord has promised to those who are the world .
# Target:		The blessings that the Lord has promised to those who overcome the world are breathtaking .
#
# Spanish:	Creo que hay una diferencia entre estar orgulloso de ciertas cosas y ser orgulloso .
# Translation:	I believe there is a difference between the things of the things .
# Target:		I believe there is a difference between being proud of certain things and being prideful .
#
# Spanish:	Cuando ella salió del agua y abrazó a su esposo tenía lágrimas de gozo .
# Translation:	When she was her to her husband and her husband had tears .
# Target:		As she emerged from the water and hugged her husband , she had tears of joy .
#
# Spanish:	“ Por la fe <unk> como extranjero en la tierra prometida como en tierra <unk>
# Translation:	“ By faith in the earth as the earth as the promised earth as the earth shall send forth in the earth as the earth .
# Target:		“ By faith he <unk> in the land of promise , as in a strange country .
#
# Spanish:	Según recuerdo , esas planchas tenían más o menos diez páginas con palabras escritas ,
# Translation:	I remember these two weeks , or less than 10 pages with the words of the words , with the words , or more than 10 pages .
# Target:		As I recall , the model plates had 10 or so metal pages with words written on them .
#
# Spanish:	Allí obtuvo una licenciatura , una maestría y un doctorado — todos en Economía .
# Translation:	There was a bachelor ’s degree , a master and a bachelor ’s degree in the United States .
# Target:		There he earned a bachelor of arts degree , a master of arts degree , and a PhD — all in economics .
#
# Spanish:	Sin que lo supiera , mi madre estaba parada en la puerta de la habitación .
# Translation:	Without what I knew that my mother was at the door of the door .
# Target:		<unk> to me , my mother was standing in the doorway .
#
# Spanish:	Y los exhorto a ayudar a otras personas a buscar sus datos de historia familiar .
# Translation:	And I would help others to help others to seek their family history .
# Target:		And I urge you to help other people identify their family histories .
#
# Spanish:	Véase <unk> W. <unk> , en Conference Report , abril de 1955 , pág. 117 .
# Translation:	See Adjusting to the Conference Report , Apr. 2011 , 49 ; Liahona , 49 ; Ensign , 49 .
# Target:		See Sterling W. Sill , in Conference Report , Apr. 1955 , 117 .
#
# Spanish:	Muchos de sus amigos no saben que son bienvenidos en nuestros edificios de la Iglesia .
# Translation:	Many of his friends do n’t know that are in the Church .
# Target:		Many of our friends do not know they are welcome in our Church buildings .
#
# Spanish:	Quizás a ellos les parecía que Él toleraba o incluso que aprobaba una conducta pecaminosa .
# Translation:	Perhaps them seemed to them that He was even though He used .
# Target:		Perhaps to them it looked like He was tolerating or even condoning sinful behavior .
#
# Spanish:	Un siervo tenía una deuda con su rey por la cantidad de 10 000 talentos .
# Translation:	One servant had a man with King of the king of the midst of the midst of the wicked .
# Target:		A servant was in debt to his king for the amount of 10,000 talents .
#
# Spanish:	Puede que incluso pensaran que la vida sería más fácil si se <unk> del árbol .
# Translation:	It can have felt that the lives would be easier to be discouraged .
# Target:		Maybe they thought if they turned away from the tree , life would be easier .
#
# Spanish:	Las decisiones que tomen en el diario vivir determinarán lo que les suceda más adelante .
# Translation:	The choices we make the decisions that will be more than you .
# Target:		The decisions you make in your daily life will determine what happens to you later .
#
# Spanish:	Vi santidad en el semblante de Evangeline , una joven de trece años de Ghana .
# Translation:	I saw the beauty of a young man ’s storehouse .
# Target:		I saw holiness in the countenance of Evangeline , a 13-year - old girl in Ghana .
#
# Spanish:	El Señor explicó la relación entre nuestro valor y Su gran sacrificio expiatorio cuando dijo :
# Translation:	The Lord explained the Lord and our great courage and His atoning sacrifice when He said :
# Target:		The Lord explained the relationship between our worth and His great atoning sacrifice when He said :
#
# Spanish:	Cuando miramos los ojos de un bebé , nos viene a la memoria la canción :
# Translation:	When we look at a baby ’s baby , we comes to the song :
# Target:		When we look into the eyes of a tiny infant , we are reminded of the song :
#
# Spanish:	Como siempre , podemos ver a Jesucristo , nuestro ejemplo perfecto , como el modelo .
# Translation:	As we can always see Jesus Christ , our perfect example , the pattern of the pattern of Jesus Christ .
# Target:		As always , we can look to our perfect example , Jesus Christ , for a pattern .
#
# Spanish:	Ustedes son hijos e hijas de Dios , hijos del convenio y <unk> del reino .
# Translation:	You are children and daughters of God ’s covenant children .
# Target:		You are sons and daughters of God , children of the covenant , and builders of the kingdom .
#
# Spanish:	Hubo muchos que notaron y mencionaron esa unidad , y lo hicieron de distintas formas .
# Translation:	There were many of that followed and unity , and with ways .
# Target:		There were many who saw and expressed this unity , and they did so in a variety of ways .
#
# Spanish:	Estaría como antes de conocer la Iglesia , cuando buscaba conocimiento , fe y esperanza .
# Translation:	You will be as the Church , when he looked at hope , and hope .
# Target:		I would be just like I was before I found the Church , when I was searching for knowledge , faith , and hope .
#
# Spanish:	( 49 ) Sidney Going escoge servir en una misión en lugar de jugar al rugby .
# Translation:	( 2001 ) Going to serve a mission in a mission .
# Target:		( 49 ) Sidney Going chooses a mission over rugby .
#
# Spanish:	El Templo de Sapporo se edificó al norte de Japón , en un lugar llamado Hokkaido .
# Translation:	The Temple was found in the Japan of Japan , in Japan , a place .
# Target:		The Sapporo Temple is built in northern Japan in a place called Hokkaido .
#
# Spanish:	La pareja sonrió y dijo : “ ¡ Pensamos que nunca nos lo <unk> ! ” .
# Translation:	The couple told us , “ We “ We never forget that we would never be done ! ”
# Target:		The couple smiled and said , “ We thought you would never ask . ”
#
# Spanish:	El Salvador percibía la firmeza o la debilidad de la fe de los que lo rodeaban .
# Translation:	The Savior will then be able to your faith of faith that those who serve .
# Target:		The Savior perceived the strength or weakness in the faith of those around Him .
#
# Spanish:	Después , medité sobre la Santa Cena , de la que participamos cada semana para recordarle .
# Translation:	I pondered the sacrament , the sacrament , we partake of the week for each week to remember .
# Target:		I then pondered about the sacrament we partake of every week in remembrance of Him .
#
# Spanish:	Se propone que sostengamos al élder Steven E. Snow como Historiador y Registrador de la Iglesia .
# Translation:	It is proposed that we sustain Elder Snow as Elder Snow and the Church .
# Target:		It is proposed that we sustain Elder Steven E. Snow as Church Historian and Recorder .
#
# Spanish:	Véanse 1 Nefi <unk> ; 2 Nefi <unk> ; Jacob 4:7 ; Doctrina y Convenios 122:8 .
# Translation:	See 1 Nephi 27:14 ; 2 Nephi 2:25 ; Jacob 4:7 ; Doctrine and Covenants 64:34 .
# Target:		See 1 Nephi <unk> ; 2 Nephi <unk> ; Jacob 4:7 ; Doctrine and Covenants 122:8 .
#
# Spanish:	" la cual procede de la presencia de Dios para llenar la inmensidad del espacio " .
# Translation:	" the course of God ’s presence of God ’s kingdom . "
# Target:		It <unk> " forth from the presence of God to fill the immensity of space . "
#
# Spanish:	Que Dios los bendiga y los haga capaces de lograrlo . En el nombre de Jesucristo .
# Translation:	May God bless the name of the name of Jesus Christ .
# Target:		God bless and make them equal to it , in the name of Jesus Christ , amen .
#
# Spanish:	Les leía cuentos antes de dormir y oraba con ellos antes de ponerlos en la cama .
# Translation:	I read them before them before them and prayed before them on the bed .
# Target:		I read them bedtime stories and said prayers with them before tucking them into bed at night .
#
# Spanish:	Todos queremos compartir el Evangelio restaurado y , afortunadamente , miles se están bautizando cada semana ;
# Translation:	We all share the restored gospel and the restored gospel are made .
# Target:		We all want to share the restored gospel , and gratefully , thousands are baptized each week .
#
# Spanish:	Salmos 27:1 ; véase también “ Jesús es mi luz ” , Himnos , Nº 42 .
# Translation:	Psalm 82:6 ; see also “ Jesus is my light , ” Hymns , ” Hymns , no .
# Target:		Psalm 27:1 ; see also “ The Lord Is My Light , ” Hymns , no . 89 .
#
# Spanish:	Nos preparamos conscientemente para la sagrada ordenanza y renovamos y <unk> nuestras sagradas promesas al Señor .
# Translation:	We prepare ourselves for the sacred ordinance and we partake of our sacred promises .
# Target:		We consciously prepare ourselves for the sacred ordinance . We renew and confirm our sacred promises to the Lord .
#
# Spanish:	Como saben , acaba de ser sostenida y comenzará oficialmente su servicio cuando regresen en julio .
# Translation:	As you know you are serving and to the service will begin to the service .
# Target:		She was just sustained , as you know , and will officially begin her service upon their return in July .
#
# Spanish:	Septiembre de 2016 Sesión General de Mujeres Sesión del sábado por la tarde 24 de septiembre de 2016
# Translation:	October 2016 General Session
# Target:		September 2016 General Women ’s Session Saturday Evening September 24 , 2016
#
# Spanish:	Cuando un ángel le preguntó a Nefi : “ ¿ <unk> la condescendencia de Dios ? ” .
# Translation:	When a angel asked to Nephi : “ Do you “ shipshape ? ”
# Target:		When an angel asked Nephi , “ <unk> thou the condescension of God ? ”
#
# Spanish:	De hecho , el discipulado no es una <unk> en absoluto , sino una invitación para todos .
# Translation:	Indeed , the discipleship is not a way , but a invitation to all a invitation to all a invitation to all .
# Target:		In fact , discipleship is not a competition at all but an invitation to all .
#
# Spanish:	Véase Enseñanzas de los presidentes de la Iglesia : Joseph F. Smith , 1999 , pág. 25 .
# Translation:	See Teachings of Presidents of the Church : Joseph F. Smith ( 1997 ) , 17 .
# Target:		Teachings of Presidents of the Church : Joseph F. Smith ( 1998 ) , 23 .
#
# Spanish:	Si demostramos amor y respecto , incluso en circunstancias adversas , llegaremos a ser más como Cristo .
# Translation:	If we look at the love and even though we will become more like Christ .
# Target:		If we show love and respect even in adverse circumstances , we become more like Christ .
#
# Spanish:	Sabíamos que , en última instancia , ellos tendrían que depender del Señor , no de nosotros .
# Translation:	We knew that in the last , that the Lord ’s way , the Lord did not be the Lord .
# Target:		We knew that ultimately they would need to depend on the Lord , not on us .
#
# Spanish:	Es por medio del Espíritu Santo que podemos " conocer la verdad de todas las cosas " .
# Translation:	It is through the Holy Ghost that we can know the truth of all things . "
# Target:		It is through the Holy Ghost that we can " know the truth of all things . "
#
# Spanish:	Él me preguntó si el Libro de Mormón era verdadero y si José Smith era un profeta .
# Translation:	He asked if the Book of Mormon was true and true and the Prophet Joseph Smith was a prophet .
# Target:		He asked me if the Book of Mormon was true and if Joseph Smith was a prophet .
#
# Spanish:	En un tono muy firme , me dijo que yo no podía hacer eso cuando hablara allí .
# Translation:	In a very strong , I told me that I could not do not do n’t know there .
# Target:		In very firm tones she told me that I could not do that when I spoke there .
#
# Spanish:	Recientemente conocí a una hermana en México que entiende lo que significa magnificar su llamamiento con fe .
# Translation:	I met a sister in Mexico that the university means to keep his call with faith .
# Target:		I recently met a sister in Mexico who understands what it means to magnify her calling with faith .
#
# Spanish:	No caminemos sin <unk> de la belleza de los gloriosos paisajes terrenales y espirituales que nos rodean .
# Translation:	Let us not walk without the beauty of the glorious spiritual beauty and spiritual and those around us .
# Target:		Let us not walk unaware of the beauty of the glorious earthly and spiritual landscapes that surround us .
#
# Spanish:	Estos miembros deben saber que el llamamiento de servir como obispo provino del Señor , por revelación .
# Translation:	These members must know that the call of the bishop of the Lord ’s revelation .
# Target:		These members have to know the call to serve as a bishop came from the Lord , by revelation .
#
# Spanish:	Y después oren para agradecerle la oportunidad de servir y para saber qué podrían hacer a continuación .
# Translation:	And pray for the opportunity to serve and serve and how to know what you can do .
# Target:		And then pray to give thanks for the opportunity to serve and to know what you might do next .
#
# Spanish:	<unk> a esos nuevos miembros porque creían que una vez satisfechas sus necesidades temporales , se <unk> .
# Translation:	They wept over the new members who felt a successful needs , your spiritual needs , the needs of their needs .
# Target:		They <unk> these new members because they believed that once their temporal needs had been met , they would fall away .
#
# Spanish:	Ruego que así sea , es mi solemne y humilde oración . En el nombre de Jesucristo .
# Translation:	I pray that is my solemn and solemn prayer .
# Target:		That this may be so is my solemn and humble prayer , in the name of Jesus Christ , our Master , amen .
#
# Translation:	Elder Brown was a bachelor ’s degree and a master of the University of the New Zealand of New Zealand .
# Target:		Elder Ardern received bachelor ’s and master ’s degrees in education from the University of <unk> in New Zealand .
#
# Spanish:	Mantengan la visión del templo , la santa casa del Señor , por siempre en sus corazones y mentes .
# Translation:	Let ’s vision of the temple , the Lord ’s holy house , and always in their minds and minds .
# Target:		Retain the vision of the temple — the Savior ’s holy house — ever in your hearts and minds .
#
# Spanish:	Al escuchar a esta mujer joven testificar : “ Centro mi vida en Jesucristo ” , obtuve mi respuesta .
# Translation:	As I hear this young woman : “ My life in my life , ” he took my response . ”
# Target:		When this young woman testified , “ I center my life on Jesus Christ , ” I had the answer .
#
# Spanish:	En este análisis de la Iglesia como el cuerpo de Cristo , debemos siempre tener en mente dos aspectos .
# Translation:	In this discussion as the Church as the body of Christ , we must always have a mind .
# Target:		In this discussion of the Church as the body of Christ , we must always bear in mind two things .
#
# Spanish:	Cada vez que lo mirara , debía pensar en el destino eterno que el Padre Celestial tiene para mí .
# Translation:	Each time , I tried to look at the eternal destiny that Heavenly Father has the Father has to me .
# Target:		Each time I looked at it , I was to think about the eternal destiny that Heavenly Father has for me .
#
# Spanish:	Hermanos , ¡ asegurémonos de colocar la palanca de “ hacerlo ” en la posición de “ ahora ” !
# Translation:	Brethren , please “ to “ to “ do ” in the position now “ I now now now now ! ”
# Target:		Brethren , let ’s make sure to set our “ do it ” switch always to the “ now ” position !
#
# Spanish:	Hemos recordado al Salvador , el Señor Jesucristo , mientras hemos sido conmovidos por himnos de alabanza a Él .
# Translation:	We have reminded the Savior , the Lord Jesus Christ , as we have been touched by Him .
# Target:		We have remembered our Savior , the Lord Jesus Christ , as we have been touched by hymns of praise to Him .
#
# Spanish:	Decía : “ Dígale a un hombre que hay tres trillones de estrellas en el universo y le creerá .
# Translation:	He said , “ a man who are three of the universe in the universe and cried out and cried out of the universe .
# Target:		It went like this : “ Tell a man there are trillions of stars in the universe , and he ’ll believe you .
#
# Spanish:	Debemos tener cuidado al usar frases permanentes como “ siempre … ” o “ nunca … ” al disciplinar .
# Translation:	We must have the care of “ even as “ always “ never action . ”
# Target:		We need to be careful , therefore , about using permanent phrases such as “ You always … ” or “ You never … ” when disciplining .
#
# Spanish:	Sentí la impresión de que , sí , el élder Cowan debía regresar a casa y esperar que lo <unk> .
# Translation:	I felt impressed to him , Elder Cowan , Elder Cowan should return home and wait to wait to wait to wait to wait .
# Target:		I felt impressed that , yes , Elder Cowan should return home and await <unk> .
#
# Spanish:	Emma Smith recopiló una colección de himnos que apareció por primera vez en este himnario de Kirtland , en 1836 .
# Translation:	Emma Smith entered a new book of hymns that the first time of the Kirtland , in the Kirtland , in the Kirtland .
# Target:		Emma Smith assembled a collection of hymns which first appeared in this Kirtland hymnal in 1836 .
#
# Spanish:	Presten atención a lo que ustedes sientan a medida que <unk> esos deberes al servicio que prestan en su familia .
# Translation:	Listen to you to feel your own way to be able to those service in their family .
# Target:		Be sensitive to what you feel as I apply these duties to your service in your family .
#
# Spanish:	Hermanos , como seguidores de Jesucristo , cada uno de ustedes puede vivir de acuerdo con las enseñanzas de Él .
# Translation:	Brethren , as followers of Jesus Christ , each of you can live with the teachings of the teachings of Him .
# Target:		Brethren , as followers of Jesus Christ , each of you can live in accord with His teachings .
#
# Spanish:	Hermanos , tenemos el <unk> y especial privilegio , como poseedores del sacerdocio , de poner el sacerdocio a trabajar .
# Translation:	Brethren , we have a special privilege and privilege to the priesthood holders of priesthood holders to work .
# Target:		Brethren , it is our great and special privilege as priesthood holders to put the priesthood to work .
#
# Spanish:	Dos de los pilares esenciales que sostienen el plan de felicidad del Padre Celestial son el matrimonio y la familia .
# Translation:	Two of the essential role of the plan of happiness are the Father of the marriage and family .
# Target:		Two of the vital pillars that sustain Father in Heaven ’s plan of happiness are marriage and the family .
#
# Spanish:	Estas son las promesas relacionadas con los convenios de las ordenanzas del templo ; véase también Doctrina y Convenios <unk> .
# Translation:	These are the promises associated with covenants of the temple ordinances of the temple and Covenants 64:34 .
# Target:		These are the promises associated with the covenants in the temple ordinances ; see also Doctrine and Covenants <unk> .
#
# Spanish:	No solo se rechazó su sugerencia , sino que oímos que había sido reprendido severa y públicamente en esa ocasión .
# Translation:	I did n’t put his shoes , but that I was n’t just taken and put on that he was in that time .
# Target:		Not only was his opinion rejected , but we heard that he was severely and publicly rebuked in that occasion .
#
# Spanish:	¿ <unk> Dios hasta que hayamos hecho todo el esfuerzo antes de intervenir en nuestra vida con Su gracia salvadora ?
# Translation:	Do we have done to have done all the effort before our lives ?
# Target:		Does God wait until we ’ve expended every effort before He will intervene in our lives with His saving grace ?
#
# Spanish:	Mientras manejaba a casa aquella noche , me pregunté : “ ¿ Qué clase de padre será Pablo ? ” .
# Translation:	While I asked that night , I asked , “ What a father will be ? ”
# Target:		When I drove home that night , I asked myself , “ What kind of father will Pablo be ? ”
#
# Spanish:	En respuesta a nuestros gritos , nuestro padre corrió a socorrernos , y nos salvó de los peligros del río .
# Translation:	In response to our father , our father would take care and be saved the dangers of the dangers River .
# Target:		In response to our cries , our father ran to the rescue , saving us from the dangers of the river .
#
# Spanish:	Otra persona que respondió a mi pregunta dijo : " Yo no tuve vida hasta leer el Libro de Mormón .
# Translation:	Another person responded to my question : " I had not heard the Book of Mormon to read the Book of Mormon .
# Target:		Another respondent to my question said : " I did not have a life until I read the Book of Mormon .
#
# Spanish:	Pero “ Samuel no había conocido aún a Jehová , ni la palabra de Jehová le había sido revelada ” .
# Translation:	“ But Samuel had never known to the Lord , the word of the Lord had been revealed unto him . ”
# Target:		But “ Samuel did not yet know the Lord , neither was the word of the Lord yet revealed unto him . ”
#
# Spanish:	¿ Recuerdan la primera vez que leyeron un versículo de las Escrituras y sintieron que el Señor les hablaba personalmente ?
# Translation:	Remember the first time that a verse of verse of the scriptures and the scriptures and spoke to them ?
# Target:		Do you remember the first time you read a verse of scripture and felt as if the Lord was speaking to you personally ?
#
# Spanish:	¡ Cuando procuramos “ completar ” y no “ competir ” es mucho más fácil animarnos unos a los otros !
# Translation:	When we seek “ shipshape and “ the “ most easy ” is easier to be easier to another !
# Target:		It is proposed that we sustain the following as new Area Seventies : Luis R. <unk> , David A. <unk> , <unk> S. <unk> , David L. <unk> , L. Todd <unk> , <unk> <unk> , <unk> <unk> Chang , Pablo H. <unk> , Raymond A. Cutler , Fernando P. <unk> <unk> , José Luiz <unk> <unk> , Aleksandr A. <unk> , I. Raymond <unk> , Carlos R. <unk> Jr. , Jorge A. García , Gary F. <unk> , <unk> I. <unk> , Marcel <unk> , José <unk> , Karl D. <unk> , <unk> S. Johnson , Jay B. Jones , Anthony M. <unk> , Paul N. <unk> , John A. <unk> , <unk> S. <unk> , Artur J. <unk> , Elie K. <unk> , Juan C. <unk> , Anthony <unk> , James R. Rasband , Carlos G. <unk> Jr. , Martin C. Rios , Johnny F. <unk> , K. Roy <unk> , and <unk> Villanueva .
#
# Spanish:	Se propone que sostengamos a los siguientes hermanos como nuevos Setentas de Área : Ian S. Ardern , Philip K. <unk> , René J. <unk> , Renato <unk> , Paul D. M. Christensen , <unk> G. R. <unk> , Donald D. <unk> , George R. Donaldson , <unk> B. <unk> , Christian <unk> , Craig G. <unk> , <unk> L. <unk> , Jack N. Gerard , M. Keith <unk> , Brent J. <unk> , <unk> Chang Juan , George M. <unk> , <unk> O. <unk> , Alexander T. Mestre , Arayik V. Minasyan , T. Jackson <unk> , S. Gifford Nielsen , <unk> F. <unk> , <unk> E. Olson , R. <unk> <unk> , Robert N. Packer , <unk> R. <unk> , <unk> A. <unk> Jr . , <unk> Pierre - <unk> , Michael J. <unk> , <unk> D. G. <unk> , <unk> K. <unk> , <unk> B. Soares , Carlos A. <unk> , <unk> de Souza <unk> , <unk> Tashiro , <unk> Villalobos , W. Christopher Waddell , Alan J. Webb , Gerardo J. <unk> , Kevin J. Worthen , Craig T. Wright y <unk> L. Wright .
# Translation:	It is proposed that we sustain the following as new Area Seventies : George Q. Cannon , James E. Koelliker , Ammon , Paul , Paul , Paul , Paul , Paul , Russell M. Christensen , S. Lewis D. Todd Christofferson , Gary B. Sabin , S. Lewis D. Todd Christofferson , S. Lewis D. Todd Christofferson ,
# Target:		All in favor , please signify .

# %% [markdown]
# <div id="disqus_thread"></div>
# <script>
#     /**
#      *  RECOMMENDED CONFIGURATION VARIABLES: EDIT AND UNCOMMENT THE SECTION BELOW TO INSERT DYNAMIC VALUES FROM YOUR PLATFORM OR CMS.
#      *  LEARN WHY DEFINING THESE VARIABLES IS IMPORTANT: https://disqus.com/admin/universalcode/#configuration-variables
#      */
#     /*
#     var disqus_config = function () {
#         this.page.url = PAGE_URL;  // Replace PAGE_URL with your page's canonical URL variable
#         this.page.identifier = PAGE_IDENTIFIER; // Replace PAGE_IDENTIFIER with your page's unique identifier variable
#     };
#     */
#     (function() {  // REQUIRED CONFIGURATION VARIABLE: EDIT THE SHORTNAME BELOW
#         var d = document, s = d.createElement('script');
#
#         s.src = 'https://EXAMPLE.disqus.com/embed.js';  // IMPORTANT: Replace EXAMPLE with your forum shortname!
#
#         s.setAttribute('data-timestamp', +new Date());
#         (d.head || d.body).appendChild(s);
#     })();
# </script>
# <noscript>Please enable JavaScript to view the <a href="https://disqus.com/?ref_noscript" rel="nofollow">comments powered by Disqus.</a></noscript>
